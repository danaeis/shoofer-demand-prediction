# %% [markdown]
# # Imports

# %%
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

# %% [markdown]
# # Configs

# %%
INPUT_PATH = 'datasets/'
ARIMA_PATH = 'statics/arima_predict.parquet'
OUTPUT_PATH = 'results/xgb_predictions.parquet'

START_DATE = '2023-01-01'
END_DATE = '2023-04-30'

FEATURE_LIST = ['ARIMA_predicts',
                
                'Previous_week_tip_amount',
                'Previous_2week_tip_amount',
                'Previous_day_tip_amount',

                'Previous_2week_demand',
                #'previous_2day_demand',
                'Previous_week_demand', 
                'Previous_day_demand',

                'Previous_week_extra',
                #'Previous_2week_extra',
                #'Previous_day_extra',
                
                #'Previous_2week_RatecodeID',
                'Previous_week_RatecodeID',
                #'Previous_day_RatecodeID',

                'Previous_week_congestion_surcharge',
                #'Previous_2week_congestion_surcharge',
                #'Previous_day_congestion_surcharge',

                #'Day_of_month', 
                #'Day_of_week'
                ]

TEST_START_DATE = '2023-04-1'

AUTO_TUNE = False

# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Load Data

# %%
def load_data(path, start_date: str, end_date: str):
    df = pd.read_parquet(path)
    start_date = datetime.date.fromisoformat(start_date)
    end_date = datetime.date.fromisoformat(end_date)
    filtered_df = df[(df['tpep_pickup_datetime'].dt.date >= start_date) &
                     (df['tpep_pickup_datetime'].dt.date <= end_date)]
    dataset = filtered_df.filter(items=['tpep_pickup_datetime', 'PULocationID', 'trip_distance', 'total_amount', 'passenger_count', 'fare_amount', 'extra', 
                                        'RatecodeID', 'congestion_surcharge', 'mta_tax', 'payment_type', 'tip_amount'])
    dataset['PU_date'] = pd.to_datetime(dataset['tpep_pickup_datetime'].dt.date)
    return dataset

# %%
rides_df = load_data(INPUT_PATH, START_DATE, END_DATE)

# %%
print(f'rides dataframe shape : {rides_df.shape}')
rides_df.head()
# Out:
# rides dataframe shape : (12672629, 13)
#   tpep_pickup_datetime  PULocationID  trip_distance  total_amount  \
# 0  2023-01-01 00:32:10           161           0.97         14.30
# 1  2023-01-01 00:55:08            43           1.10         16.90
# 2  2023-01-01 00:25:04            48           2.51         34.90
# 3  2023-01-01 00:03:48           138           1.90         20.85
# 4  2023-01-01 00:10:29           107           1.43         19.68
#
#    passenger_count  fare_amount  extra  RatecodeID  congestion_surcharge  \
# 0              1.0          9.3   1.00         1.0                   2.5
# 1              1.0          7.9   1.00         1.0                   2.5
# 2              1.0         14.9   1.00         1.0                   2.5
# 3              0.0         12.1   7.25         1.0                   0.0
# 4              1.0         11.4   1.00         1.0                   2.5
#
#    mta_tax  payment_type  tip_amount    PU_date
# 0      0.5             2        0.00 2023-01-01
# 1      0.5             1        4.00 2023-01-01
# 2      0.5             1       15.00 2023-01-01
# 3      0.5             1        0.00 2023-01-01
# 4      0.5             1        3.28 2023-01-01

# %%
statics_df = pd.read_parquet(ARIMA_PATH)

# %%
print(f'rides dataframe shape : {statics_df.shape}')
statics_df.head()
# Out:
# rides dataframe shape : (27772, 1)
#     0
# 0  18
# 1   0
# 2   1
# 3  86
# 4   1

# %% [markdown]
# ## Labeling

# %%
def labeling(dataset):
    '''dataset_labels_demand = (
        dataset
        .groupby(['PULocationID', 'PU_date'])['PU_date']
        .count()
        .to_frame('Demand')
        .sort_values(['PULocationID', 'PU_date'], ascending=[True, True])
        .reset_index()
        .rename(columns={'PULocationID': 'Location', 'PU_date': 'Date'})
    )'''
    dataset_labels = (
                rides_df.groupby(['PULocationID', 'PU_date'])
                .agg({'trip_distance': 'sum', 'tpep_pickup_datetime': 'count', 'total_amount': 'max', 'passenger_count': 'median' ,'fare_amount': 'max', 'extra': 'max',
                      'RatecodeID': 'max', 'congestion_surcharge': 'median', 'tip_amount': 'sum'})
                .reset_index()
                .rename(columns={'trip_distance': 'trip_dists', 'tpep_pickup_datetime': 'Demand', 'PULocationID': 'Location', 'PU_date': 'Date'})
)

    locations = pd.DataFrame(dataset_labels['Location'].unique(), columns=['Location'])
    dates = pd.DataFrame(dataset_labels['Date'].unique(), columns=['Date'])

    location_date_df = (
        locations
        .merge(dates, how='cross')
        .sort_values(['Location', 'Date'], ascending=[True, True])
        .reset_index(drop=True)
    )

    labels_df = (
        location_date_df
        .merge(dataset_labels, how='left', on=['Location', 'Date'])
        .fillna(value=0)
    )

    return labels_df

# %%
labeled_df = labeling(rides_df)

# %%
labeled_df.corr()
# Out:
# C:\Users\bardia\AppData\Local\Temp\ipykernel_14744\88742821.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   labeled_df.corr()
#                       Location  trip_dists    Demand  total_amount  \
# Location              1.000000    0.062112  0.170603      0.108762
# trip_dists            0.062112    1.000000  0.545723      0.419847
# Demand                0.170603    0.545723  1.000000      0.549526
# total_amount          0.108762    0.419847  0.549526      1.000000
# passenger_count       0.016235    0.056160  0.110859      0.327228
# fare_amount           0.101904    0.412153  0.499474      0.979716
# extra                 0.132396    0.349627  0.699069      0.617278
# RatecodeID            0.004881   -0.038136  0.017784      0.165308
# congestion_surcharge  0.090494    0.272568  0.652117      0.492916
# tip_amount            0.116440    0.738038  0.872268      0.582771
#
#                       passenger_count  fare_amount     extra  RatecodeID  \
# Location                     0.016235     0.101904  0.132396    0.004881
# trip_dists                   0.056160     0.412153  0.349627   -0.038136
# Demand                       0.110859     0.499474  0.699069    0.017784
# total_amount                 0.327228     0.979716  0.617278    0.165308
# passenger_count              1.000000     0.304021  0.238119    0.383892
# fare_amount                  0.304021     1.000000  0.544366    0.163487
# extra                        0.238119     0.544366  1.000000    0.076257
# RatecodeID                   0.383892     0.163487  0.076257    1.000000
# congestion_surcharge         0.184746     0.420301  0.786686   -0.054519
# tip_amount                   0.088691     0.557005  0.575552   -0.033141
#
#                       congestion_surcharge  tip_amount
# Location                          0.090494    0.116440
# trip_dists                        0.272568    0.738038
# Demand                            0.652117    0.872268
# total_amount                      0.492916    0.582771
# passenger_count                   0.184746    0.088691
# fare_amount                       0.420301    0.557005
# extra                             0.786686    0.575552
# RatecodeID                       -0.054519   -0.033141
# congestion_surcharge              1.000000    0.487463
# tip_amount                        0.487463    1.000000

# %%
print(f'labeled dataframe shape : {labeled_df.shape}')
labeled_df.head()
# Out:
# labeled dataframe shape : (31440, 11)
#    Location       Date  trip_dists  Demand  total_amount  passenger_count  \
# 0         1 2023-01-01       17.71    40.0        276.00              6.0
# 1         1 2023-01-02       27.54    31.0        279.50              4.0
# 2         1 2023-01-03        0.40    27.0        351.00              5.0
# 3         1 2023-01-04        2.60     7.0        204.69              4.0
# 4         1 2023-01-05       17.50    15.0        213.00              4.0
#
#    fare_amount  extra  RatecodeID  congestion_surcharge  tip_amount
# 0    86.040500    0.0         5.0                   0.0      393.43
# 1    87.085806    0.0         5.0                   0.0      363.76
# 2    82.731852    0.0         5.0                   0.0      296.50
# 3   107.390000    0.0         5.0                   0.0      194.64
# 4    89.377333    0.0         5.0                   0.0      200.13

# %% [markdown]
# ## Add Feature

# %%
def feature_engineering(dataset, statics_df):
    dataset['Previous_day_demand'] = dataset.groupby(['Location'])['Demand'].shift(1)
    dataset['previous_2day_demand'] = dataset.groupby(['Location'])['Demand'].shift(2)
    dataset['Previous_week_demand'] = dataset.groupby(['Location'])['Demand'].shift(7)
    dataset['Previous_2week_demand'] = dataset.groupby(['Location'])['Demand'].shift(14)

    dataset['Previous_week_tip_amount'] = dataset.groupby(['Location'])['tip_amount'].shift(7)
    dataset['Previous_2week_tip_amount'] = dataset.groupby(['Location'])['tip_amount'].shift(14)
    dataset['Previous_day_tip_amount'] = dataset.groupby(['Location'])['tip_amount'].shift(1)

    dataset['Previous_week_extra'] = dataset.groupby(['Location'])['extra'].shift(7)
    dataset['Previous_2week_extra'] = dataset.groupby(['Location'])['extra'].shift(14)
    dataset['Previous_day_extra'] = dataset.groupby(['Location'])['extra'].shift(1)
    
    dataset['Previous_week_RatecodeID'] = dataset.groupby(['Location'])['RatecodeID'].shift(7)
    dataset['Previous_2week_RatecodeID'] = dataset.groupby(['Location'])['RatecodeID'].shift(14)
    dataset['Previous_day_RatecodeID'] = dataset.groupby(['Location'])['RatecodeID'].shift(1)

    dataset['Previous_week_congestion_surcharge'] = dataset.groupby(['Location'])['congestion_surcharge'].shift(7)
    dataset['Previous_2week_congestion_surcharge'] = dataset.groupby(['Location'])['congestion_surcharge'].shift(14)
    dataset['Previous_day_congestion_surcharge'] = dataset.groupby(['Location'])['congestion_surcharge'].shift(1)


    dataset['Day_of_week'] = dataset['Date'].dt.dayofweek   
    dataset['Day_of_month'] = dataset['Date'].dt.day

    dataset = dataset.sort_values(by = ['Date', 'Location'])
    dataset['ARIMA_predicts'] = None
    start_index = len(dataset) - len(statics_df)
    end_index = len(dataset)
    dataset.iloc[start_index:end_index, dataset.columns.get_loc('ARIMA_predicts')] = statics_df
    dataset['ARIMA_predicts'] = dataset['ARIMA_predicts'].astype('float')
    dataset = dataset.sort_values(by = ['Location', 'Date'])
    
    return dataset

# %%
features_df = feature_engineering(labeled_df, statics_df)
features_df.dropna(inplace = True)

# %%
print(f'features dataframe shape : {features_df.shape}')
features_df.head()
# Out:
# features dataframe shape : (27772, 30)
#     Location       Date  trip_dists  Demand  total_amount  passenger_count  \
# 14         1 2023-01-15        0.70    19.0        181.00              4.0
# 15         1 2023-01-16       20.90    21.0        213.76              4.0
# 16         1 2023-01-17       20.80    18.0        145.20              3.0
# 17         1 2023-01-18       21.00    10.0        151.20              2.0
# 18         1 2023-01-19        0.06     9.0        158.50              3.0
#
#     fare_amount  extra  RatecodeID  congestion_surcharge  ...  \
# 14    83.149474    0.0         5.0                   0.0  ...
# 15    72.167143    0.0         5.0                   0.0  ...
# 16    71.450000    0.0         5.0                   0.0  ...
# 17    73.275000    0.0         5.0                   0.0  ...
# 18    91.722222    0.0         5.0                   0.0  ...
#
#     Previous_day_extra  Previous_week_RatecodeID  Previous_2week_RatecodeID  \
# 14                 0.0                       5.0                        5.0
# 15                 0.0                       5.0                        5.0
# 16                 0.0                       5.0                        5.0
# 17                 0.0                       5.0                        5.0
# 18                 0.0                       5.0                        5.0
#
#     Previous_day_RatecodeID  Previous_week_congestion_surcharge  \
# 14                      5.0                                 0.0
# 15                      5.0                                 0.0
# 16                      5.0                                 0.0
# 17                      5.0                                 0.0
# 18                      5.0                                 0.0
#
#     Previous_2week_congestion_surcharge  Previous_day_congestion_surcharge  \
# 14                                  0.0                                0.0
# 15                                  0.0                                0.0
# 16                                  0.0                                0.0
# 17                                  0.0                                0.0
# 18                                  0.0                                0.0
#
#     Day_of_week  Day_of_month  ARIMA_predicts
# 14            6            15            18.0
# 15            0            16            18.0
# 16            1            17            19.0
# 17            2            18            17.0
# 18            3            19            12.0
#
# [5 rows x 30 columns]

# %%
features_df.corr()
# Out:
# C:\Users\bardia\AppData\Local\Temp\ipykernel_14744\2297156001.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   features_df.corr()
#                                          Location  trip_dists    Demand  \
# Location                             1.000000e+00    0.016560  0.170959
# trip_dists                           1.655998e-02    1.000000  0.061732
# Demand                               1.709591e-01    0.061732  1.000000
# total_amount                         1.098235e-01    0.043727  0.548697
# passenger_count                      1.022003e-01    0.062466  0.603338
# fare_amount                         -4.260710e-02   -0.013945 -0.126895
# extra                                7.819233e-02    0.035018  0.513865
# RatecodeID                          -6.643417e-02   -0.028318 -0.262799
# congestion_surcharge                 9.181351e-02    0.063318  0.657677
# tip_amount                           1.170473e-01    0.047802  0.872966
# Previous_day_demand                  1.709947e-01    0.062204  0.975984
# previous_2day_demand                 1.710381e-01    0.059671  0.946813
# Previous_week_demand                 1.710896e-01    0.063360  0.992777
# Previous_2week_demand                1.708211e-01    0.063038  0.991886
# Previous_week_tip_amount             1.175117e-01    0.049393  0.867174
# Previous_2week_tip_amount            1.174211e-01    0.048941  0.865800
# Previous_day_tip_amount              1.173047e-01    0.048250  0.852737
# Previous_week_extra                  7.940019e-02    0.034817  0.513458
# Previous_2week_extra                 7.904915e-02    0.037826  0.512278
# Previous_day_extra                   7.830486e-02    0.034080  0.510862
# Previous_week_RatecodeID            -6.529769e-02   -0.027904 -0.260133
# Previous_2week_RatecodeID           -6.312445e-02   -0.028057 -0.258212
# Previous_day_RatecodeID             -6.547101e-02   -0.027883 -0.262815
# Previous_week_congestion_surcharge   9.139103e-02    0.060708  0.654072
# Previous_2week_congestion_surcharge  9.032394e-02    0.061374  0.650276
# Previous_day_congestion_surcharge    9.175105e-02    0.060295  0.657170
# Day_of_week                         -3.698266e-15    0.004190  0.004821
# Day_of_month                         4.147200e-15   -0.004155 -0.001952
# ARIMA_predicts                       1.739109e-01    0.061389  0.985595
#
#                                      total_amount  passenger_count  \
# Location                                 0.109823         0.102200
# trip_dists                               0.043727         0.062466
# Demand                                   0.548697         0.603338
# total_amount                             1.000000         0.624873
# passenger_count                          0.624873         1.000000
# fare_amount                              0.353902        -0.000460
# extra                                    0.398505         0.474229
# RatecodeID                              -0.170701        -0.368130
# congestion_surcharge                     0.493937         0.751338
# tip_amount                               0.582222         0.489077
# Previous_day_demand                      0.546010         0.603214
# previous_2day_demand                     0.539682         0.602798
# Previous_week_demand                     0.547988         0.603190
# Previous_2week_demand                    0.546705         0.602434
# Previous_week_tip_amount                 0.580300         0.489876
# Previous_2week_tip_amount                0.579199         0.489292
# Previous_day_tip_amount                  0.579406         0.489906
# Previous_week_extra                      0.398665         0.461049
# Previous_2week_extra                     0.394556         0.459043
# Previous_day_extra                       0.389678         0.460586
# Previous_week_RatecodeID                -0.190639        -0.371365
# Previous_2week_RatecodeID               -0.191033        -0.367066
# Previous_day_RatecodeID                 -0.201045        -0.374191
# Previous_week_congestion_surcharge       0.487276         0.743285
# Previous_2week_congestion_surcharge      0.486960         0.741030
# Previous_day_congestion_surcharge        0.490746         0.745628
# Day_of_week                             -0.002321         0.013121
# Day_of_month                             0.007704        -0.002458
# ARIMA_predicts                           0.548087         0.607510
#
#                                      fare_amount     extra  RatecodeID  \
# Location                               -0.042607  0.078192   -0.066434
# trip_dists                             -0.013945  0.035018   -0.028318
# Demand                                 -0.126895  0.513865   -0.262799
# total_amount                            0.353902  0.398505   -0.170701
# passenger_count                        -0.000460  0.474229   -0.368130
# fare_amount                             1.000000 -0.044676    0.370029
# extra                                  -0.044676  1.000000   -0.275167
# RatecodeID                              0.370029 -0.275167    1.000000
# congestion_surcharge                   -0.126969  0.562104   -0.377470
# tip_amount                             -0.017578  0.519119   -0.212180
# Previous_day_demand                    -0.127182  0.490417   -0.263072
# previous_2day_demand                   -0.127470  0.472391   -0.263146
# Previous_week_demand                   -0.127291  0.509711   -0.262978
# Previous_2week_demand                  -0.126761  0.508279   -0.262581
# Previous_week_tip_amount               -0.018549  0.515599   -0.212498
# Previous_2week_tip_amount              -0.018160  0.511997   -0.212168
# Previous_day_tip_amount                -0.018695  0.503525   -0.212383
# Previous_week_extra                    -0.066454  0.703409   -0.243673
# Previous_2week_extra                   -0.069255  0.705866   -0.244830
# Previous_day_extra                     -0.071492  0.631202   -0.244582
# Previous_week_RatecodeID                0.261476 -0.246288    0.623321
# Previous_2week_RatecodeID               0.260666 -0.244276    0.631924
# Previous_day_RatecodeID                 0.249108 -0.241732    0.582989
# Previous_week_congestion_surcharge     -0.153583  0.537964   -0.369180
# Previous_2week_congestion_surcharge    -0.153792  0.534319   -0.369703
# Previous_day_congestion_surcharge      -0.157958  0.532607   -0.369295
# Day_of_week                            -0.027662 -0.076868   -0.129427
# Day_of_month                            0.003574  0.002207    0.000832
# ARIMA_predicts                         -0.128817  0.493384   -0.265091
#
#                                      congestion_surcharge  tip_amount  ...  \
# Location                                         0.091814    0.117047  ...
# trip_dists                                       0.063318    0.047802  ...
# Demand                                           0.657677    0.872966  ...
# total_amount                                     0.493937    0.582222  ...
# passenger_count                                  0.751338    0.489077  ...
# fare_amount                                     -0.126969   -0.017578  ...
# extra                                            0.562104    0.519119  ...
# RatecodeID                                      -0.377470   -0.212180  ...
# congestion_surcharge                             1.000000    0.495171  ...
# tip_amount                                       0.495171    1.000000  ...
# Previous_day_demand                              0.657298    0.849967  ...
# previous_2day_demand                             0.656582    0.825231  ...
# Previous_week_demand                             0.657471    0.865230  ...
# Previous_2week_demand                            0.655681    0.864264  ...
# Previous_week_tip_amount                         0.495240    0.990563  ...
# Previous_2week_tip_amount                        0.492653    0.988219  ...
# Previous_day_tip_amount                          0.494050    0.972753  ...
# Previous_week_extra                              0.538760    0.519871  ...
# Previous_2week_extra                             0.532220    0.518350  ...
# Previous_day_extra                               0.533741    0.510986  ...
# Previous_week_RatecodeID                        -0.365151   -0.209796  ...
# Previous_2week_RatecodeID                       -0.362727   -0.208227  ...
# Previous_day_RatecodeID                         -0.365564   -0.211858  ...
# Previous_week_congestion_surcharge               0.885407    0.489513  ...
# Previous_2week_congestion_surcharge              0.879892    0.483815  ...
# Previous_day_congestion_surcharge                0.885869    0.494213  ...
# Day_of_week                                      0.007729    0.000009  ...
# Day_of_month                                     0.002547    0.001815  ...
# ARIMA_predicts                                   0.661591    0.855310  ...
#
#                                      Previous_day_extra  \
# Location                                       0.078305
# trip_dists                                     0.034080
# Demand                                         0.510862
# total_amount                                   0.389678
# passenger_count                                0.460586
# fare_amount                                   -0.071492
# extra                                          0.631202
# RatecodeID                                    -0.244582
# congestion_surcharge                           0.533741
# tip_amount                                     0.510986
# Previous_day_demand                            0.513539
# previous_2day_demand                           0.490897
# Previous_week_demand                           0.509521
# Previous_2week_demand                          0.508533
# Previous_week_tip_amount                       0.510285
# Previous_2week_tip_amount                      0.506964
# Previous_day_tip_amount                        0.519643
# Previous_week_extra                            0.637075
# Previous_2week_extra                           0.633207
# Previous_day_extra                             1.000000
# Previous_week_RatecodeID                      -0.242007
# Previous_2week_RatecodeID                     -0.240581
# Previous_day_RatecodeID                       -0.275452
# Previous_week_congestion_surcharge             0.533661
# Previous_2week_congestion_surcharge            0.532053
# Previous_day_congestion_surcharge              0.562589
# Day_of_week                                    0.013478
# Day_of_month                                  -0.003336
# ARIMA_predicts                                 0.504497
#
#                                      Previous_week_RatecodeID  \
# Location                                            -0.065298
# trip_dists                                          -0.027904
# Demand                                              -0.260133
# total_amount                                        -0.190639
# passenger_count                                     -0.371365
# fare_amount                                          0.261476
# extra                                               -0.246288
# RatecodeID                                           0.623321
# congestion_surcharge                                -0.365151
# tip_amount                                          -0.209796
# Previous_day_demand                                 -0.260310
# previous_2day_demand                                -0.260385
# Previous_week_demand                                -0.260127
# Previous_2week_demand                               -0.259844
# Previous_week_tip_amount                            -0.210450
# Previous_2week_tip_amount                           -0.209960
# Previous_day_tip_amount                             -0.210138
# Previous_week_extra                                 -0.273794
# Previous_2week_extra                                -0.239825
# Previous_day_extra                                  -0.242007
# Previous_week_RatecodeID                             1.000000
# Previous_2week_RatecodeID                            0.616539
# Previous_day_RatecodeID                              0.581936
# Previous_week_congestion_surcharge                  -0.374218
# Previous_2week_congestion_surcharge                 -0.364862
# Previous_day_congestion_surcharge                   -0.364491
# Day_of_week                                         -0.127454
# Day_of_month                                        -0.007060
# ARIMA_predicts                                      -0.262319
#
#                                      Previous_2week_RatecodeID  \
# Location                                             -0.063124
# trip_dists                                           -0.028057
# Demand                                               -0.258212
# total_amount                                         -0.191033
# passenger_count                                      -0.367066
# fare_amount                                           0.260666
# extra                                                -0.244276
# RatecodeID                                            0.631924
# congestion_surcharge                                 -0.362727
# tip_amount                                           -0.208227
# Previous_day_demand                                  -0.258420
# previous_2day_demand                                 -0.258450
# Previous_week_demand                                 -0.258318
# Previous_2week_demand                                -0.257840
# Previous_week_tip_amount                             -0.208740
# Previous_2week_tip_amount                            -0.208600
# Previous_day_tip_amount                              -0.208610
# Previous_week_extra                                  -0.245882
# Previous_2week_extra                                 -0.271729
# Previous_day_extra                                   -0.240581
# Previous_week_RatecodeID                              0.616539
# Previous_2week_RatecodeID                             1.000000
# Previous_day_RatecodeID                               0.574103
# Previous_week_congestion_surcharge                   -0.363211
# Previous_2week_congestion_surcharge                  -0.372009
# Previous_day_congestion_surcharge                    -0.360833
# Day_of_week                                          -0.122053
# Day_of_month                                          0.003366
# ARIMA_predicts                                       -0.260404
#
#                                      Previous_day_RatecodeID  \
# Location                                           -0.065471
# trip_dists                                         -0.027883
# Demand                                             -0.262815
# total_amount                                       -0.201045
# passenger_count                                    -0.374191
# fare_amount                                         0.249108
# extra                                              -0.241732
# RatecodeID                                          0.582989
# congestion_surcharge                               -0.365564
# tip_amount                                         -0.211858
# Previous_day_demand                                -0.262750
# previous_2day_demand                               -0.262863
# Previous_week_demand                               -0.262907
# Previous_2week_demand                              -0.262519
# Previous_week_tip_amount                           -0.212322
# Previous_2week_tip_amount                          -0.212012
# Previous_day_tip_amount                            -0.212454
# Previous_week_extra                                -0.243981
# Previous_2week_extra                               -0.240810
# Previous_day_extra                                 -0.275452
# Previous_week_RatecodeID                            0.581936
# Previous_2week_RatecodeID                           0.574103
# Previous_day_RatecodeID                             1.000000
# Previous_week_congestion_surcharge                 -0.368051
# Previous_2week_congestion_surcharge                -0.367108
# Previous_day_congestion_surcharge                  -0.377537
# Day_of_week                                         0.005189
# Day_of_month                                        0.000518
# ARIMA_predicts                                     -0.264929
#
#                                      Previous_week_congestion_surcharge  \
# Location                                                       0.091391
# trip_dists                                                     0.060708
# Demand                                                         0.654072
# total_amount                                                   0.487276
# passenger_count                                                0.743285
# fare_amount                                                   -0.153583
# extra                                                          0.537964
# RatecodeID                                                    -0.369180
# congestion_surcharge                                           0.885407
# tip_amount                                                     0.489513
# Previous_day_demand                                            0.653834
# previous_2day_demand                                           0.653177
# Previous_week_demand                                           0.654613
# Previous_2week_demand                                          0.652661
# Previous_week_tip_amount                                       0.491997
# Previous_2week_tip_amount                                      0.489109
# Previous_day_tip_amount                                        0.489043
# Previous_week_extra                                            0.562184
# Previous_2week_extra                                           0.533120
# Previous_day_extra                                             0.533661
# Previous_week_RatecodeID                                      -0.374218
# Previous_2week_RatecodeID                                     -0.363211
# Previous_day_RatecodeID                                       -0.368051
# Previous_week_congestion_surcharge                             1.000000
# Previous_2week_congestion_surcharge                            0.882606
# Previous_day_congestion_surcharge                              0.882362
# Day_of_week                                                    0.008958
# Day_of_month                                                   0.004308
# ARIMA_predicts                                                 0.658294
#
#                                      Previous_2week_congestion_surcharge  \
# Location                                                        0.090324
# trip_dists                                                      0.061374
# Demand                                                          0.650276
# total_amount                                                    0.486960
# passenger_count                                                 0.741030
# fare_amount                                                    -0.153792
# extra                                                           0.534319
# RatecodeID                                                     -0.369703
# congestion_surcharge                                            0.879892
# tip_amount                                                      0.483815
# Previous_day_demand                                             0.650351
# previous_2day_demand                                            0.649935
# Previous_week_demand                                            0.650626
# Previous_2week_demand                                           0.649471
# Previous_week_tip_amount                                        0.484895
# Previous_2week_tip_amount                                       0.484620
# Previous_day_tip_amount                                         0.483958
# Previous_week_extra                                             0.538039
# Previous_2week_extra                                            0.557618
# Previous_day_extra                                              0.532053
# Previous_week_RatecodeID                                       -0.364862
# Previous_2week_RatecodeID                                      -0.372009
# Previous_day_RatecodeID                                        -0.367108
# Previous_week_congestion_surcharge                              0.882606
# Previous_2week_congestion_surcharge                             1.000000
# Previous_day_congestion_surcharge                               0.877388
# Day_of_week                                                     0.007009
# Day_of_month                                                   -0.001802
# ARIMA_predicts                                                  0.654689
#
#                                      Previous_day_congestion_surcharge  \
# Location                                                      0.091751
# trip_dists                                                    0.060295
# Demand                                                        0.657170
# total_amount                                                  0.490746
# passenger_count                                               0.745628
# fare_amount                                                  -0.157958
# extra                                                         0.532607
# RatecodeID                                                   -0.369295
# congestion_surcharge                                          0.885869
# tip_amount                                                    0.494213
# Previous_day_demand                                           0.658038
# previous_2day_demand                                          0.657114
# Previous_week_demand                                          0.657662
# Previous_2week_demand                                         0.655463
# Previous_week_tip_amount                                      0.496332
# Previous_2week_tip_amount                                     0.492980
# Previous_day_tip_amount                                       0.496878
# Previous_week_extra                                           0.539313
# Previous_2week_extra                                          0.535694
# Previous_day_extra                                            0.562589
# Previous_week_RatecodeID                                     -0.364491
# Previous_2week_RatecodeID                                    -0.360833
# Previous_day_RatecodeID                                      -0.377537
# Previous_week_congestion_surcharge                            0.882362
# Previous_2week_congestion_surcharge                           0.877388
# Previous_day_congestion_surcharge                             1.000000
# Day_of_week                                                  -0.000666
# Day_of_month                                                  0.004862
# ARIMA_predicts                                                0.661982
#
#                                       Day_of_week  Day_of_month  \
# Location                            -3.698266e-15  4.147200e-15
# trip_dists                           4.189981e-03 -4.154817e-03
# Demand                               4.820910e-03 -1.952406e-03
# total_amount                        -2.320819e-03  7.704225e-03
# passenger_count                      1.312128e-02 -2.458479e-03
# fare_amount                         -2.766181e-02  3.574295e-03
# extra                               -7.686768e-02  2.207181e-03
# RatecodeID                          -1.294269e-01  8.321663e-04
# congestion_surcharge                 7.729054e-03  2.546995e-03
# tip_amount                           9.485269e-06  1.815178e-03
# Previous_day_demand                  3.049611e-02 -8.089288e-04
# previous_2day_demand                 2.054966e-02  2.011653e-03
# Previous_week_demand                 5.760417e-03 -6.682579e-04
# Previous_2week_demand                7.236422e-03  1.805952e-03
# Previous_week_tip_amount             1.398726e-03  2.394347e-03
# Previous_2week_tip_amount            2.515764e-03  1.550285e-03
# Previous_day_tip_amount              1.660456e-02  2.510754e-03
# Previous_week_extra                 -7.473126e-02 -1.027833e-02
# Previous_2week_extra                -6.908773e-02  1.360855e-03
# Previous_day_extra                   1.347801e-02 -3.335674e-03
# Previous_week_RatecodeID            -1.274541e-01 -7.060212e-03
# Previous_2week_RatecodeID           -1.220529e-01  3.365712e-03
# Previous_day_RatecodeID              5.188552e-03  5.180312e-04
# Previous_week_congestion_surcharge   8.958085e-03  4.308470e-03
# Previous_2week_congestion_surcharge  7.008738e-03 -1.802275e-03
# Previous_day_congestion_surcharge   -6.658669e-04  4.862143e-03
# Day_of_week                          1.000000e+00 -1.896507e-02
# Day_of_month                        -1.896507e-02  1.000000e+00
# ARIMA_predicts                       1.378102e-02 -7.156290e-04
#
#                                      ARIMA_predicts
# Location                                   0.173911
# trip_dists                                 0.061389
# Demand                                     0.985595
# total_amount                               0.548087
# passenger_count                            0.607510
# fare_amount                               -0.128817
# extra                                      0.493384
# RatecodeID                                -0.265091
# congestion_surcharge                       0.661591
# tip_amount                                 0.855310
# Previous_day_demand                        0.989775
# previous_2day_demand                       0.961431
# Previous_week_demand                       0.984277
# Previous_2week_demand                      0.983645
# Previous_week_tip_amount                   0.855246
# Previous_2week_tip_amount                  0.854507
# Previous_day_tip_amount                    0.860327
# Previous_week_extra                        0.496633
# Previous_2week_extra                       0.493561
# Previous_day_extra                         0.504497
# Previous_week_RatecodeID                  -0.262319
# Previous_2week_RatecodeID                 -0.260404
# Previous_day_RatecodeID                   -0.264929
# Previous_week_congestion_surcharge         0.658294
# Previous_2week_congestion_surcharge        0.654689
# Previous_day_congestion_surcharge          0.661982
# Day_of_week                                0.013781
# Day_of_month                              -0.000716
# ARIMA_predicts                             1.000000
#
# [29 rows x 29 columns]

# %%
pca = PCA()
pca.fit(features_df[FEATURE_LIST])


cumsum = np.cumsum(pca.explained_variance_ratio_)
cumsum, len(FEATURE_LIST), pca.feature_names_in_
# Out:
# (array([0.96820216, 0.98325203, 0.99603354, 0.9996278 , 0.99982006,
#         0.99992767, 0.99997096, 0.99999999, 1.        , 1.        ]),
#  10,
#  array(['ARIMA_predicts', 'Previous_week_tip_amount',
#         'Previous_2week_tip_amount', 'Previous_day_tip_amount',
#         'Previous_2week_demand', 'Previous_week_demand',
#         'Previous_day_demand', 'Previous_week_extra',
#         'Previous_week_RatecodeID', 'Previous_week_congestion_surcharge'],
#        dtype=object))

# %% [markdown]
# ## Split Train and Test Data

# %%
def train_test_splitting(dataset, TEST_START_DATE):

    train_df = dataset[dataset['Date'] < TEST_START_DATE]
    test_df = dataset[dataset['Date'] >= TEST_START_DATE]

    return train_df, test_df

# %%
train_df, test_df = train_test_splitting(features_df, TEST_START_DATE)

# %%
print(f'train dataframe shape : {train_df.shape}')
train_df.head()
# Out:
# train dataframe shape : (19912, 30)
#     Location       Date  trip_dists  Demand  total_amount  passenger_count  \
# 14         1 2023-01-15        0.70    19.0        181.00              4.0
# 15         1 2023-01-16       20.90    21.0        213.76              4.0
# 16         1 2023-01-17       20.80    18.0        145.20              3.0
# 17         1 2023-01-18       21.00    10.0        151.20              2.0
# 18         1 2023-01-19        0.06     9.0        158.50              3.0
#
#     fare_amount  extra  RatecodeID  congestion_surcharge  ...  \
# 14    83.149474    0.0         5.0                   0.0  ...
# 15    72.167143    0.0         5.0                   0.0  ...
# 16    71.450000    0.0         5.0                   0.0  ...
# 17    73.275000    0.0         5.0                   0.0  ...
# 18    91.722222    0.0         5.0                   0.0  ...
#
#     Previous_day_extra  Previous_week_RatecodeID  Previous_2week_RatecodeID  \
# 14                 0.0                       5.0                        5.0
# 15                 0.0                       5.0                        5.0
# 16                 0.0                       5.0                        5.0
# 17                 0.0                       5.0                        5.0
# 18                 0.0                       5.0                        5.0
#
#     Previous_day_RatecodeID  Previous_week_congestion_surcharge  \
# 14                      5.0                                 0.0
# 15                      5.0                                 0.0
# 16                      5.0                                 0.0
# 17                      5.0                                 0.0
# 18                      5.0                                 0.0
#
#     Previous_2week_congestion_surcharge  Previous_day_congestion_surcharge  \
# 14                                  0.0                                0.0
# 15                                  0.0                                0.0
# 16                                  0.0                                0.0
# 17                                  0.0                                0.0
# 18                                  0.0                                0.0
#
#     Day_of_week  Day_of_month  ARIMA_predicts
# 14            6            15            18.0
# 15            0            16            18.0
# 16            1            17            19.0
# 17            2            18            17.0
# 18            3            19            12.0
#
# [5 rows x 30 columns]

# %%
print(f'test dataframe shape : {test_df.shape}')
test_df.head()
# Out:
# test dataframe shape : (7860, 30)
#     Location       Date  trip_dists  Demand  total_amount  passenger_count  \
# 90         1 2023-04-01        0.02    13.0        194.10              4.0
# 91         1 2023-04-02        1.83    17.0        156.55              4.0
# 92         1 2023-04-03       18.13     9.0        154.00              3.0
# 93         1 2023-04-04        0.01    12.0        145.00              4.0
# 94         1 2023-04-05        0.58    18.0        157.20              4.0
#
#     fare_amount  extra  RatecodeID  congestion_surcharge  ...  \
# 90    78.119231    0.0         5.0                   0.0  ...
# 91    91.463529    0.0         5.0                   0.0  ...
# 92    67.388889    0.0         5.0                   0.0  ...
# 93   103.383333    0.0         5.0                   0.0  ...
# 94    87.236667    0.0         5.0                   0.0  ...
#
#     Previous_day_extra  Previous_week_RatecodeID  Previous_2week_RatecodeID  \
# 90                 0.0                       5.0                        5.0
# 91                 0.0                       5.0                        5.0
# 92                 0.0                       5.0                        5.0
# 93                 0.0                       5.0                        5.0
# 94                 0.0                       5.0                        3.0
#
#     Previous_day_RatecodeID  Previous_week_congestion_surcharge  \
# 90                      5.0                                 0.0
# 91                      5.0                                 0.0
# 92                      5.0                                 0.0
# 93                      5.0                                 0.0
# 94                      5.0                                 0.0
#
#     Previous_2week_congestion_surcharge  Previous_day_congestion_surcharge  \
# 90                                  0.0                                0.0
# 91                                  0.0                                0.0
# 92                                  0.0                                0.0
# 93                                  0.0                                0.0
# 94                                  0.0                                0.0
#
#     Day_of_week  Day_of_month  ARIMA_predicts
# 90            5             1            13.0
# 91            6             2            13.0
# 92            0             3            15.0
# 93            1             4            11.0
# 94            2             5            13.0
#
# [5 rows x 30 columns]

# %% [markdown]
# # Model Training

# %% [markdown]
# ## **Ridge Regression**

# %% [markdown]
# ### Model Tuning

# %%
def grid_search(model, test_parameters, train_data, cv = None, feature_list = FEATURE_LIST):
    gs = GridSearchCV(
        estimator = model, 
        param_grid = test_parameters, 
        scoring = 'neg_root_mean_squared_error', 
        cv = cv, 
        n_jobs = -1
        )
    
    gs.fit(train_data[feature_list], train_data['Demand'])
    return gs.best_params_, gs.best_score_

# %%
model = Ridge()
best_params, best_score = grid_search(
    model, 
    {'alpha':[0, 1, 10, 100, 1000]},
    train_df, 
    cv = 5, 
    feature_list = FEATURE_LIST
    )

print(best_params, best_score)
# Out:
# {'alpha': 0} -95.01082778269145

# %% [markdown]
# ### Prediction

# %%
def model_predict(model, train_data, test_data, feature_list):

    model.fit(train_data[feature_list], train_data['Demand'])


    train_predict_df  = model.predict(train_data[feature_list])
    test_predict_df  = model.predict(test_data[feature_list])

    return train_predict_df, test_predict_df

# %%
model = Ridge(**best_params)
train_prediction_df , test_prediction_df  = model_predict(model, train_df, test_df, FEATURE_LIST)

# %% [markdown]
# ### Visualization

# %%
def add_day_of_year(data):
    data['day_year'] = 0
    start_date = data['Date'].min()

    for index, row in data.iterrows():

        curr_date = row['Date']
        day_number = (curr_date - start_date).days

        data.at[index, 'day_year'] = day_number
    return data

# %%
def prediction_visualization(train_data, test_data, train_prediction_df, test_prediction_df):


    train_data = add_day_of_year(train_data)
    test_data = add_day_of_year(test_data)

    predicted_train_df = train_data
    predicted_test_df = test_data
    predicted_train_df['Predicted'] = train_prediction_df
    predicted_test_df['Predicted'] = test_prediction_df

    train_data = train_data.groupby('day_year')['Demand'].sum()
    test_data = test_data.groupby('day_year')['Demand'].sum()
    predicted_train_df = predicted_train_df.groupby('day_year')['Predicted'].sum()
    predicted_test_df = predicted_test_df.groupby('day_year')['Predicted'].sum()

    plt.title('Train')
    plt.plot(train_data)
    plt.plot(predicted_train_df)
    plt.legend(["Real Value", "Predicted"], loc ="lower right")
    plt.show()

    plot_length = len(test_data)
    plt.title('Test')
    plt.plot(test_data)
    plt.plot(predicted_test_df)
    plt.legend(["Real Value", "Predicted"], loc ="lower right")
    plt.show()

# %%
prediction_visualization(train_df, test_df, train_prediction_df, test_prediction_df)
# Out:
# C:\Users\bardia\AppData\Local\Temp\ipykernel_14744\2975102461.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['day_year'] = 0
# C:\Users\bardia\AppData\Local\Temp\ipykernel_14744\2975102461.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['day_year'] = 0
# C:\Users\bardia\AppData\Local\Temp\ipykernel_14744\2246591508.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predicted_train_df['Predicted'] = train_prediction_df
# C:\Users\bardia\AppData\Local\Temp\ipykernel_14744\2246591508.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predicted_test_df['Predicted'] = test_prediction_df

# %% [markdown]
# ### Evaluation

# %%
def evaluate(metric, metric_name, true_values, predicted_values):
    print(f'{metric_name} : {metric(true_values, predicted_values)}')

# %%
def evaluation(model_name, train_data, test_data, train_prediction_df, test_prediction_df):
    print(f'{model_name} train scores:')


    evaluate(mean_absolute_error, 'MAE', train_data['Demand'], train_prediction_df)
    evaluate(mean_squared_error, 'MSE', train_data['Demand'], train_prediction_df)
    evaluate(mean_absolute_percentage_error, 'MAPE', train_data['Demand'], train_prediction_df)

    print(f'{model_name} test scores:')

    evaluate(mean_absolute_error, 'MAE', test_data['Demand'], test_prediction_df)
    evaluate(mean_squared_error, 'MSE', test_data['Demand'], test_prediction_df)
    evaluate(mean_absolute_percentage_error, 'MAPE', test_data['Demand'], test_prediction_df)

# %%
evaluation('Ridge Regression', train_df, test_df, train_prediction_df, test_prediction_df)
# Out:
# Ridge Regression train scores:
# MAE : 31.134536516968033
# MSE : 10168.368888800354
# MAPE : 1081836063274080.9
# Ridge Regression test scores:
# MAE : 33.144661333140576
# MSE : 10097.745406254022
# MAPE : 1164674416311480.0

# %% [markdown]
# # File Saving

# %%
def save_predictions(dataset, path):
    dataset.to_parquet(path, index=False)

# %%
def prediction_labeling(pred_df, labeled_df):
    pred_df = pd.DataFrame(pred_df, columns = ['Predicted_demand'])
    labeled_df.reset_index(inplace = True)
    labeled_prediction_df = labeled_df[['Location', 'Date']]
    labeled_prediction_df['Predicted_demand'] = pred_df
    return labeled_prediction_df

# %%
labeled_prediction_df = prediction_labeling(test_prediction_df, test_df)
# Out:
# C:\Users\bardia\AppData\Local\Temp\ipykernel_14744\1857597426.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled_prediction_df['Predicted_demand'] = pred_df

# %%
print(f'labeled prediction dataframe shape : {labeled_prediction_df.shape}')
labeled_prediction_df.head()
# Out:
# labeled prediction dataframe shape : (7860, 3)
#    Location       Date  Predicted_demand
# 0         1 2023-04-01         16.370947
# 1         1 2023-04-02         18.906560
# 2         1 2023-04-03          8.478683
# 3         1 2023-04-04         11.162216
# 4         1 2023-04-05          8.794914

# %%
save_predictions(labeled_prediction_df, OUTPUT_PATH)
